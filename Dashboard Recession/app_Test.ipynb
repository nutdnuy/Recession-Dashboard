# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import ffn
import scipy
import datetime as dt

import seaborn as sns
import matplotlib.pyplot as plt
from Investment import Backtestlib
# Out:
# /Users/nuthdanai/Desktop/Dashboard Recession
# ##########

# %%
Even =  pd.read_excel("Data/recession.xlsm", index_col=0)

# %%
Even.Event.tolist()
# Out:
# ['Black Monday',
#  'Early recession (Iraq invaded Kuwait)',
#  'Japanese asset price bubble',
#  'Black Wednesday',
#  'Asian financial crisis',
#  'Russian financial crisis',
#  'Dot-com bubble',
#  'September 11 attacks',
#  'Chinese stock bubble ',
#  'Subprime crisis',
#  'Quantitative Easing 1',
#  'Dubai debt standstill',
#  'European sovereign debt crisis',
#  'Flash crash',
#  'Quantitative Easing 2',
#  'Quantitative Easing 3',
#  'Cyprus financial crisis',
#  'Chinese stock market selloff',
#  'Fed raises interest rates',
#  'UK votes to leave EU',
#  'Quantitative tightening',
#  'Cryptocurrency crash',
#  'COVID-19 lockdowns',
#  'Quantitative Easing 4',
#  'Successful trials for COVID-19 vaccines',
#  'Russian invasion in Ukraine',
#  'Fed raises interest rates']

# %%
option = 'Black Monday'

# %%
Even[Even["Event"] == option ]
# Out:
#                    Event
# Date
# 1987-10-19  Black Monday

# %%
df_asset_1 = pd.read_csv("Data/EVEN_TEST_New_1.csv", index_col="Date")
df_asset_2 =  pd.read_csv("Data/EVEN_TEST_New_2.csv", index_col="Date")
df_asset_2["Price Close"] = df_asset_2["Close Price"]
df_asset = pd.concat([df_asset_1,  df_asset_2])[["Instrument", "Price Close"]]
df_asset.index = pd.to_datetime(df_asset.index)
df_asset.index = df_asset.index.date

# %%
df_asset["date"] = df_asset.index

# %%
df_asset
# Out:
#            Instrument  Price Close        date
# 1988-02-12     .SPXTR      258.870  1988-02-12
# 1988-03-31     .SPXTR      261.150  1988-03-31
# 1988-05-27     .SPXTR      257.401  1988-05-27
# 1988-07-01     .SPXTR      276.856  1988-07-01
# 1988-09-02     .SPXTR      271.188  1988-09-02
# ...               ...          ...         ...
# 2021-12-27     IGSB.O       53.885  2021-12-27
# 2021-12-28     IGSB.O       53.880  2021-12-28
# 2021-12-29     IGSB.O       53.870  2021-12-29
# 2021-12-30     IGSB.O       53.900  2021-12-30
# 2021-12-31     IGSB.O       53.880  2021-12-31
#
# [144067 rows x 3 columns]

# %%
Evens["Type Even"]
# Out:
# Date
# 1987-10-19                  Financial Market Turmoil and Crises
# 1990-07-01                                 Geopolitical Factors
# 1991-12-01               Asset Bubbles and Speculative Excesses
# 1992-09-16    Political and Geopolitical Events Impacting Fi...
# 1997-07-02                  Financial Market Turmoil and Crises
# 1998-08-17                  Financial Market Turmoil and Crises
# 2000-03-10               Asset Bubbles and Speculative Excesses
# 2001-09-11                                 Geopolitical Factors
# 2007-02-27               Asset Bubbles and Speculative Excesses
# 2008-09-16                  Financial Market Turmoil and Crises
# 2008-11-01     Central Bank Policies and Monetary Interventions
# 2009-11-27                  Financial Market Turmoil and Crises
# 2010-04-27                  Financial Market Turmoil and Crises
# 2010-05-06                  Financial Market Turmoil and Crises
# 2010-11-01     Central Bank Policies and Monetary Interventions
# ...

# %%
df_asset.Instrument.unique().tolist()
# Out:
# ['.SPXTR',
#  '.HSIDVN',
#  'MXWS.L',
#  'NDXEX.DE',
#  '.NIFTRI',
#  '.N225NTR',
#  '.BSESNTR',
#  '.SX5GR',
#  'GLD',
#  'EEM',
#  '.SETI',
#  '.IDCOT7TR',
#  '.MIWD00000PUS',
#  'BOND.K',
#  '.MIAPJ0000PUS',
#  'IGSB.O',
#  '.SETITRI',
#  '.MERG0BC']

# %%
option_asset = ".SPXTR"


df_asset[df_asset['Instrument'] == option_asset ]["Price Close"].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_asset.index = pd.to_datetime(df_asset.index, format='%d-%m-%Y')
df['date'] = df['datetime'].dt.date
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/nr/3vs7wdfj1mn1333tl23g4vy00000gn/T/ipykernel_31491/3910788312.py in <module>
# ----> 1 df_asset.index = pd.to_datetime(df_asset.index, format='%d-%m-%Y')
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1075             result = _convert_and_box_cache(arg, cache_array, name=arg.name)
#    1076         else:
# -> 1077             result = convert_listlike(arg, format, name=arg.name)
#    1078     elif is_list_like(arg):
#    1079         try:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/tools/datetimes.py in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     428
# ...

# %%
df_asset.index = pd.to_datetime(df_asset.index)
df_asset.index = df_asset.index.date
# Out:
#                           Instrument  Price Close
# Date
# 1988-02-12 00:00:00+00:00     .SPXTR      258.870
# 1988-03-31 00:00:00+00:00     .SPXTR      261.150
# 1988-05-27 00:00:00+00:00     .SPXTR      257.401
# 1988-07-01 00:00:00+00:00     .SPXTR      276.856
# 1988-09-02 00:00:00+00:00     .SPXTR      271.188
# ...                              ...          ...
# 2021-12-27 00:00:00+00:00     IGSB.O       53.885
# 2021-12-28 00:00:00+00:00     IGSB.O       53.880
# 2021-12-29 00:00:00+00:00     IGSB.O       53.870
# 2021-12-30 00:00:00+00:00     IGSB.O       53.900
# 2021-12-31 00:00:00+00:00     IGSB.O       53.880
#
# [84984 rows x 2 columns]

# %%
price["return"] = np.log( price["Price Close"] /  price["Price Close"].shift(1))

# %%
import streamlit as st
import plotly.express as px

# Create a DataFrame
df = df_asset

# Create a Plotly figure
fig = px.line(df, x=index, y='Price Close')

# Display the figure in Streamlit
st.plotly_chart(fig)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/nr/3vs7wdfj1mn1333tl23g4vy00000gn/T/ipykernel_31491/2464819439.py in <module>
#       6
#       7 # Create a Plotly figure
# ----> 8 fig = px.line(df, x='x', y='y')
#       9
#      10 # Display the figure in Streamlit
#
# ~/opt/anaconda3/lib/python3.9/site-packages/plotly/express/_chart_types.py in line(data_frame, x, y, line_group, color, line_dash, symbol, hover_name, hover_data, custom_data, text, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, error_x, error_x_minus, error_y, error_y_minus, animation_frame, animation_group, category_orders, labels, orientation, color_discrete_sequence, color_discrete_map, line_dash_sequence, line_dash_map, symbol_sequence, symbol_map, markers, log_x, log_y, range_x, range_y, line_shape, render_mode, title, template, width, height)
# ...

# %%
Price_return = np.log( price["Price Close"] /  price["Price Close"].shift(1))

# %%
topdrowdown , df_dd = Backtestlib.group_drawdown(Price_return)
# Out:
# /Users/nuthdanai/Desktop/Dashboard Recession/Investment/Backtestlib.py:201: FutureWarning:
#
# Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.

# %%
# Create a Plotly Table
fig = go.Figure(data=[go.Table(
    header=dict(values=df_dd.columns.tolist(),
                fill_color='paleturquoise',
                align='left'),
    cells=dict(values=[df_dd[col].tolist() for col in df_dd.columns],
               fill_color='lavender',
               align='left'))
])

fig.show()

# %%
df_dd
# Out:
#      start_date    end_date  previous_peeks  drowdown drowdown_date  \
# 0    2007-07-03  2013-03-28     7489.199197 -0.492585    2009-02-13
# 1    2000-09-01  2007-01-12     7105.448167 -0.453193    2003-02-14
# 2    2021-12-23  2023-07-28    24257.473883 -0.226037    2022-06-17
# 3    2018-08-31  2019-05-24    14929.183253 -0.196396    2018-12-24
# 4    2020-02-14  2020-09-04    17433.684624 -0.188573    2020-04-09
# ..          ...         ...             ...       ...           ...
# 97   1991-12-24  1991-12-24     1703.859635  0.000000    1991-12-24
# 98   2013-11-27  2013-11-27     8673.249449  0.000000    2013-11-27
# 99   1993-12-23  1993-12-23     2103.782497  0.000000    1993-12-23
# 100  2014-04-17  2014-04-17     9015.713785  0.000000    2014-04-17
# 101  1992-11-25  1992-11-25     1879.332007  0.000000    1992-11-25
#
#      drowdown_length  recovery_length  total_length
# 0                 16               38            54
# ...

# %%
Backtestlib.drawdown(Price_return)
# Out:
#                   Wealth  Previous Peak  Drawdown
# 1988-02-12           NaN            NaN       NaN
# 1988-03-31   1008.768950    1008.768950  0.000000
# 1988-05-27    994.182378    1008.768950 -0.014460
# 1988-07-01   1066.620828    1066.620828  0.000000
# 1988-09-02   1044.557554    1066.620828 -0.020685
# ...                  ...            ...       ...
# 2023-04-06  21185.264012   24257.473883 -0.126650
# 2023-05-26  21741.989086   24257.473883 -0.103699
# 2023-06-16  22798.618200   24257.473883 -0.060140
# 2023-07-03  23044.180754   24257.473883 -0.050017
# 2023-07-28  23710.202317   24257.473883 -0.022561
#
# [849 rows x 3 columns]

# %%
df_Drawdown = Backtestlib.drawdown(Price_return).Drawdown
st.area_chart(df_Drawdown.Drawdown)
# Out:
# <AxesSubplot:>

# %%
topdrowdown_ = topdrowdown.reset_index(level=1).set_index('level_1', drop=True).head(7)
topdrowdown_ .rename_axis('Date', inplace=True)
topdrowdown_
# Out:
#             Previous Peak  Drawdown
# Date
# 2009-02-13    7489.199197 -0.492585
# 2003-02-14    7105.448167 -0.453193
# 2022-06-17   24257.473883 -0.226037
# 2018-12-24   14929.183253 -0.196396
# 2020-04-09   17433.684624 -0.188573
# 1998-09-04    5461.928840 -0.160384
# 2016-02-12   10475.873350 -0.118393

# %%
Evens
# Out:
#                                               Event
# Date
# 1987-10-19                             Black Monday
# 1990-07-01    Early recession (Iraq invaded Kuwait)
# 1991-12-01              Japanese asset price bubble
# 1992-09-16                          Black Wednesday
# 1997-07-02                   Asian financial crisis
# 1998-08-17                 Russian financial crisis
# 2000-03-10                           Dot-com bubble
# 2001-09-11                     September 11 attacks
# 2007-02-27                    Chinese stock bubble
# 2008-09-16                          Subprime crisis
# 2008-11-01                    Quantitative Easing 1
# 2009-11-27                    Dubai debt standstill
# 2010-04-27           European sovereign debt crisis
# 2010-05-06                              Flash crash
# 2010-11-01                    Quantitative Easing 2
# 2012-09-01                    Quantitative Easing 3
# 2013-04-01                  Cyprus financial crisis
# ...

# %%
import pandas as pd
import numpy as np

# Assume df1 and df2 are your two dataframes and 'date' is the date column
df1 = topdrowdown_ 
df2 = Evens

df1['key'] = 1
df2['key'] = 1


merged = pd.merge(df1, df2, on='key', suffixes=('_1', '_2')).drop('key', axis=1)

merged['date_diff'] = (merged['Date_1'] - merged['Date_2']).dt.days.abs()

idx = merged.groupby(['Date_1'])['date_diff'].idxmin()

closest_dates = merged.loc[idx, ['Date_1', 'Date_2']]

print(closest_dates)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date_1'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
merged
# Out:
#      Previous Peak  Drawdown                                    Event
# 0      7489.199197 -0.492585                             Black Monday
# 1      7489.199197 -0.492585    Early recession (Iraq invaded Kuwait)
# 2      7489.199197 -0.492585              Japanese asset price bubble
# 3      7489.199197 -0.492585                          Black Wednesday
# 4      7489.199197 -0.492585                   Asian financial crisis
# ..             ...       ...                                      ...
# 184   10475.873350 -0.118393                       COVID-19 lockdowns
# 185   10475.873350 -0.118393                    Quantitative Easing 4
# 186   10475.873350 -0.118393  Successful trials for COVID-19 vaccines
# 187   10475.873350 -0.118393              Russian invasion in Ukraine
# 188   10475.873350 -0.118393                Fed raises interest rates
#
# [189 rows x 3 columns]

# %%
df_dd .head(10)
# Out:
#    start_date    end_date  previous_peeks  drowdown drowdown_date  \
# 0  2007-07-03  2013-03-28     7489.199197 -0.492585    2009-02-13
# 1  2000-09-01  2007-01-12     7105.448167 -0.453193    2003-02-14
# 2  2021-12-23  2023-07-28    24257.473883 -0.226037    2022-06-17
# 3  2018-08-31  2019-05-24    14929.183253 -0.196396    2018-12-24
# 4  2020-02-14  2020-09-04    17433.684624 -0.188573    2020-04-09
# 5  1998-07-02  1998-09-04     5461.928840 -0.160384    1998-09-04
# 6  2015-05-22  2016-07-01    10475.873350 -0.118393    2016-02-12
# 7  1990-07-03  1990-12-31     1487.713650 -0.114825    1990-11-21
# 8  2000-01-14  2000-07-03     6858.019811 -0.083630    2000-02-18
# 9  1989-12-29  1990-04-12     1438.304026 -0.055327    1990-02-16
#
#    drowdown_length  recovery_length  total_length
# 0               16               38            54
# 1               24              571           595
# 2                6               12            18
# ...

# %%
df_dd
# Out:
#      start_date    end_date  previous_peeks  drowdown drowdown_date  \
# 0    2007-07-03  2013-03-28     7489.199197 -0.492585    2009-02-13
# 1    2000-09-01  2007-01-12     7105.448167 -0.453193    2003-02-14
# 2    2021-12-23  2023-07-28    24257.473883 -0.226037    2022-06-17
# 3    2018-08-31  2019-05-24    14929.183253 -0.196396    2018-12-24
# 4    2020-02-14  2020-09-04    17433.684624 -0.188573    2020-04-09
# ..          ...         ...             ...       ...           ...
# 97   1991-12-24  1991-12-24     1703.859635  0.000000    1991-12-24
# 98   2013-11-27  2013-11-27     8673.249449  0.000000    2013-11-27
# 99   1993-12-23  1993-12-23     2103.782497  0.000000    1993-12-23
# 100  2014-04-17  2014-04-17     9015.713785  0.000000    2014-04-17
# 101  1992-11-25  1992-11-25     1879.332007  0.000000    1992-11-25
#
#      drowdown_length  recovery_length  total_length
# 0                 16               38            54
# ...

# %%
Evens =  pd.read_excel("Data/recession.xlsm", index_col=0)
Evens
# Out:
#                                               Event  \
# Date
# 1987-10-19                             Black Monday
# 1990-07-01    Early recession (Iraq invaded Kuwait)
# 1991-12-01              Japanese asset price bubble
# 1992-09-16                          Black Wednesday
# 1997-07-02                   Asian financial crisis
# 1998-08-17                 Russian financial crisis
# 2000-03-10                           Dot-com bubble
# 2001-09-11                     September 11 attacks
# 2007-02-27                    Chinese stock bubble
# 2008-09-16                          Subprime crisis
# 2008-11-01                    Quantitative Easing 1
# 2009-11-27                    Dubai debt standstill
# 2010-04-27           European sovereign debt crisis
# 2010-05-06                              Flash crash
# 2010-11-01                    Quantitative Easing 2
# 2012-09-01                    Quantitative Easing 3
# 2013-04-01                  Cyprus financial crisis
# ...

# %%
Evens['recession_start'] = (Evens['Event'] > Evens['Event'].shift(1))
recession_starts = Evens[Evens['recession_start'] == True]
recession_starts = recession_starts

# %%
recession_starts
# Out:
#                                               Event  \
# Date
# 1990-07-01    Early recession (Iraq invaded Kuwait)
# 1991-12-01              Japanese asset price bubble
# 1998-08-17                 Russian financial crisis
# 2001-09-11                     September 11 attacks
# 2008-09-16                          Subprime crisis
# 2010-04-27           European sovereign debt crisis
# 2010-05-06                              Flash crash
# 2010-11-01                    Quantitative Easing 2
# 2012-09-01                    Quantitative Easing 3
# 2015-12-01                Fed raises interest rates
# 2016-06-23                     UK votes to leave EU
# 2020-03-01                    Quantitative Easing 4
# 2020-11-01  Successful trials for COVID-19 vaccines
#
#                                                     Type Even  recession_start
# Date
# 1990-07-01                               Geopolitical Factors             True
# ...

# %%
recession_starts.head(3).index
# Out:
# DatetimeIndex(['1990-07-01', '1991-12-01', '1998-08-17', '2001-09-11',
#                '2008-09-16', '2010-04-27', '2010-05-06', '2010-11-01',
#                '2012-09-01', '2015-12-01', '2016-06-23', '2020-03-01',
#                '2020-11-01'],
#               dtype='datetime64[ns]', name='Date', freq=None)

# %%
data_i =  price
dic_aa = {} 

for date in recession_starts.head(3).index:
    
    lst = []
    
    for i_start in range(20, 110 , 5) :
       # print("i_Start " , i_start)
        dic_of_return = {}
        
        for i_End in range(20, 110 , 5) :
        #    print("i_End " , i_End)
            dic_of_return[i_End] = data_i[data_i.index > pd.to_datetime( date) -  pd.DateOffset(days=i_start)].head(i_start+i_End)["Price Close"].pct_change(i_start+i_End -1)[-1]

        
        df = pd.DataFrame(dic_of_return, index=["return"]).T
        df["day after event"] = df.index
        df["day before event"] = i_start
        
        lst.append(df)
    
    aa = pd.concat(lst).pivot_table(values='return', index=['day after event'], columns='day before event') *100  
    Event = recession_starts[recession_starts.index == date].Event[0]
    print(Event)
    dic_aa[Event] = aa
    
    mask = np.triu(np.ones_like(aa, dtype=bool))

    
    
    
    
    # Set up the matplotlib figure
    f, ax = plt.subplots(figsize=(11, 9))
    plt.title(date)
    sns.set_style('whitegrid')

    # Generate a custom diverging colormap
    cmap = sns.diverging_palette(230, 20, as_cmap=True)

    # Draw the heatmap with the mask and correct aspect ratio
    sns.heatmap(aa, mask=mask, cmap="PiYG", vmax=.3, center=0,
                square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# Early recession (Iraq invaded Kuwait)
# Japanese asset price bubble
# Russian financial crisis

# %%
pd.concat(lst).pivot_table(values='return', index=['day after event'], columns='day before event') *100
# Out:
# day before event        20         25         30         35         40   \
# day after event
# 20                -1.760782   0.839930   4.332499   9.614184   9.319731
# 25                 0.839930   4.332499   9.614184   9.319731   7.226016
# 30                 4.332499   9.614184   9.319731   7.226016   8.289189
# 35                 9.614184   9.319731   7.226016   8.289189   9.711875
# 40                 9.319731   7.226016   8.289189   9.711875   9.194375
# 45                 7.226016   8.289189   9.711875   9.194375   9.787892
# 50                 8.289189   9.711875   9.194375   9.787892   7.808734
# 55                 9.711875   9.194375   9.787892   7.808734   8.988120
# 60                 9.194375   9.787892   7.808734   8.988120  10.376571
# 65                 9.787892   7.808734   8.988120  10.376571   9.773007
# 70                 7.808734   8.988120  10.376571   9.773007  13.094839
# 75                 8.988120  10.376571   9.773007  13.094839  11.427274
# ...

# %%
import pandas as pd
import numpy as np

def process_price_data(price, recession_starts, dic_aa):
    
    data_i = price

    for date in recession_starts.index:
        
        lst = []

        for i_start in range(20, 110, 5):
            dic_of_return = {}

            for i_End in range(20, 110, 5):
                dic_of_return[i_End] = data_i[data_i.index > pd.to_datetime(date) - pd.DateOffset(days=i_start)].head(i_start+i_End)["Price Close"].pct_change(i_start+i_End -1)[-1]

            df = pd.DataFrame(dic_of_return, index=["return"]).T
            df["day after event"] = df.index
            df["day before event"] = i_start

            lst.append(df)

        aa = pd.concat(lst).pivot_table(values='return', index=['day after event'], columns='day before event') *100
        
        Event = recession_starts[recession_starts.index == date].Event[0]
        print(Event)
        dic_aa[Event] = aa

        mask = np.triu(np.ones_like(aa, dtype=bool))

    return dic_aa

# %%
data_i =  price
dic_aa = {} 
recession_starts

dic_aa = process_price_data(price, recession_starts, dic_aa)
# Out:
# Early recession (Iraq invaded Kuwait)
# Japanese asset price bubble
# Russian financial crisis
# September 11 attacks
# Subprime crisis
# European sovereign debt crisis
# Flash crash
# Quantitative Easing 2
# Quantitative Easing 3
# Fed raises interest rates
# UK votes to leave EU
# Quantitative Easing 4
# Successful trials for COVID-19 vaccines

# %%
dic_aa['Early recession (Iraq invaded Kuwait)']
# Out:
# day before event         20          25          30          35          40   \
# day after event
# 20                 68.663136  101.202094  116.195454  159.653468  229.171172
# 25                101.202094  116.195454  159.653468  216.965494  286.329381
# 30                116.195454  159.653468  216.965494  279.822733  331.045027
# 35                159.653468  216.965494  279.822733  324.230868  360.201783
# 40                216.965494  279.822733  324.230868  383.209354  421.939926
# 45                279.822733  324.230868  383.209354  371.187124  445.780132
# 50                324.230868  383.209354  371.187124  366.905582  369.548335
# 55                383.209354  371.187124  366.905582  319.867910  314.370044
# 60                371.187124  366.905582  319.867910  309.902785  320.169675
# 65                366.905582  319.867910  309.902785  290.449427  230.916862
# 70                319.867910  309.902785  290.449427  220.376121  252.848686
# ...

# %%
Evens
# Out:
#                                               Event  \
# Date
# 1987-10-19                             Black Monday
# 1990-07-01    Early recession (Iraq invaded Kuwait)
# 1991-12-01              Japanese asset price bubble
# 1992-09-16                          Black Wednesday
# 1997-07-02                   Asian financial crisis
# 1998-08-17                 Russian financial crisis
# 2000-03-10                           Dot-com bubble
# 2001-09-11                     September 11 attacks
# 2007-02-27                    Chinese stock bubble
# 2008-09-16                          Subprime crisis
# 2008-11-01                    Quantitative Easing 1
# 2009-11-27                    Dubai debt standstill
# 2010-04-27           European sovereign debt crisis
# 2010-05-06                              Flash crash
# 2010-11-01                    Quantitative Easing 2
# 2012-09-01                    Quantitative Easing 3
# 2013-04-01                  Cyprus financial crisis
# ...

# %%
option = Evens.Event.tolist()[6]
option ="Subprime crisis"
dateEvent = Evens [Evens.Event == option].index[0]

# %%
price = df_asset[df_asset['Instrument'] == option_asset ]
Price_return = np.log( price["Price Close"] /  price["Price Close"].shift(1))

# %%
price = price[price.index > pd.to_datetime(dateEvent) - pd.DateOffset(days=i_start)]
price =  price[price.index < pd.to_datetime(dateEvent) - pd.DateOffset(days=i_start)]
# Out:
#            Instrument  Price Close    return
# 2000-02-22   .MERG0BC      118.133  0.005135
# 2000-02-23   .MERG0BC      117.890 -0.002059
# 2000-02-24   .MERG0BC      118.147  0.002178
# 2000-02-25   .MERG0BC      118.130 -0.000144
# 2000-02-28   .MERG0BC      117.758 -0.003154
# ...               ...          ...       ...
# 2021-12-27   .MERG0BC      351.316  0.001108
# 2021-12-28   .MERG0BC      351.395  0.000225
# 2021-12-29   .MERG0BC      350.443 -0.002713
# 2021-12-30   .MERG0BC      350.986  0.001548
# 2021-12-31   .MERG0BC      351.510  0.001492
#
# [5719 rows x 3 columns]

# %%
print(dateEvent)

print( pd.to_datetime(dateEvent) - pd.DateOffset(days=i_start))
# Out:
# 2000-03-10 00:00:00
# 2000-02-19 00:00:00

# %%
dic_tab_1 = {}
i_start = 360
i_End = 360





for asset in df_asset.Instrument.unique() :
    print(asset)
    price = df_asset[df_asset['Instrument'] == asset ]
    price["return"] = np.log( price["Price Close"] /  price["Price Close"].shift(1))
    price = price[price.index > pd.to_datetime(dateEvent) - pd.DateOffset(days=i_start)]
    price =  price[price.index < pd.to_datetime(dateEvent) + pd.DateOffset(days=i_End )]
    before_even =  price [price.index  <  pd.to_datetime(dateEvent)]
    after_even = price [price.index  <  pd.to_datetime(dateEvent)]

    
    dic_tab_1[asset] = price
# Out:
# .SPXTR
# .HSIDVN
# MXWS.L
# NDXEX.DE
# .NIFTRI
# .N225NTR
# .BSESNTR
# .SX5GR
# GLD
# EEM
# .SETI
# .IDCOT7TR
# .MIWD00000PUS
# BOND.K
# .MIAPJ0000PUS
# IGSB.O
# .SETITRI
# .MERG0BC

# %%
before_even =  price [price.index  <  pd.to_datetime(dateEvent)]
after_even = price [price.index  <  pd.to_datetime(dateEvent)]
# Out:
#            Instrument  Price Close    return
# 2008-03-03   .MERG0BC      182.767 -0.000104
# 2008-03-04   .MERG0BC      182.470 -0.001626
# 2008-03-05   .MERG0BC      181.546 -0.005077
# 2008-03-06   .MERG0BC      181.565  0.000105
# 2008-03-07   .MERG0BC      181.740  0.000963
# ...               ...          ...       ...
# 2008-09-09   .MERG0BC      181.983  0.001578
# 2008-09-10   .MERG0BC      181.463 -0.002861
# 2008-09-11   .MERG0BC      180.937 -0.002903
# 2008-09-12   .MERG0BC      179.798 -0.006315
# 2008-09-15   .MERG0BC      178.956 -0.004694
#
# [143 rows x 3 columns]

# %%
priceone = price [price <  pd.to_datetime(dateEvent)]
# Out:
#            Instrument  Price Close    return
# 2008-03-03   .MERG0BC      182.767 -0.000104
# 2008-03-04   .MERG0BC      182.470 -0.001626
# 2008-03-05   .MERG0BC      181.546 -0.005077
# 2008-03-06   .MERG0BC      181.565  0.000105
# 2008-03-07   .MERG0BC      181.740  0.000963
# ...               ...          ...       ...
# 2009-03-30   .MERG0BC      170.148  0.002784
# 2009-03-31   .MERG0BC      170.403  0.001498
# 2009-04-01   .MERG0BC      170.685  0.001654
# 2009-04-02   .MERG0BC      170.046 -0.003751
# 2009-04-03   .MERG0BC      169.366 -0.004007
#
# [288 rows x 3 columns]

# %%
pd.concat(dic_tab_1)
# Out:
#                     Instrument  Price Close    return
# .SPXTR   2008-03-20     .SPXTR    2098.4628 -0.012969
#          2008-05-23     .SPXTR    2179.0537  0.037686
#          2008-07-03     .SPXTR    2004.8674 -0.083313
#          2008-08-29     .SPXTR    2043.5319  0.019102
#          2008-11-26     .SPXTR    1423.9044 -0.361277
# ...                        ...          ...       ...
# .MERG0BC 2009-03-30   .MERG0BC     170.1480  0.002784
#          2009-03-31   .MERG0BC     170.4030  0.001498
#          2009-04-01   .MERG0BC     170.6850  0.001654
#          2009-04-02   .MERG0BC     170.0460 -0.003751
#          2009-04-03   .MERG0BC     169.3660 -0.004007
#
# [3476 rows x 3 columns]

# %%
all_returns
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
Evens =  pd.read_excel("Data/recession.xlsm", index_col=0)


df_asset_1 = pd.read_csv("Data/EVEN_TEST_New_1.csv", index_col="Date").dropna()
df_asset_2 =  pd.read_csv("Data/EVEN_TEST_New_2.csv", index_col="Date").dropna()
df_asset_2["Price Close"] = df_asset_2["Close Price"]

# %%
df_asset_1 .dropna()
# Out:
#                       Unnamed: 0 Instrument   Volume  Price Close
# Date
# 1988-02-12T00:00:00Z        4727     .SPXTR        0      258.870
# 1988-03-31T00:00:00Z        4761     .SPXTR        0      261.150
# 1988-05-27T00:00:00Z        4802     .SPXTR        0      257.401
# 1988-07-01T00:00:00Z        4827     .SPXTR        0      276.856
# 1988-09-02T00:00:00Z        4872     .SPXTR        0      271.188
# ...                          ...        ...      ...          ...
# 2023-07-25T00:00:00Z      236378     IGSB.O  2793455       50.170
# 2023-07-26T00:00:00Z      236379     IGSB.O  4930207       50.310
# 2023-07-27T00:00:00Z      236380     IGSB.O  4198096       50.130
# 2023-07-28T00:00:00Z      236381     IGSB.O  3105610       50.280
# 2023-07-28T00:00:00Z      236382     IGSB.O        0       50.280
#
# [35914 rows x 4 columns]

# %%
df_asset_2
# Out:
#                       Unnamed: 0 Instrument  Close Price  Price Close
# Date
# 2002-01-02T00:00:00Z        8349   .SETITRI     1000.000     1000.000
# 2002-01-03T00:00:00Z        8350   .SETITRI     1022.600     1022.600
# 2002-01-04T00:00:00Z        8351   .SETITRI     1034.750     1034.750
# 2002-01-07T00:00:00Z        8352   .SETITRI     1041.170     1041.170
# 2002-01-08T00:00:00Z        8353   .SETITRI     1044.330     1044.330
# ...                          ...        ...          ...          ...
# 2021-12-27T00:00:00Z      108149     IGSB.O       53.885       53.885
# 2021-12-28T00:00:00Z      108150     IGSB.O       53.880       53.880
# 2021-12-29T00:00:00Z      108151     IGSB.O       53.870       53.870
# 2021-12-30T00:00:00Z      108152     IGSB.O       53.900       53.900
# 2021-12-31T00:00:00Z      108153     IGSB.O       53.880       53.880
#
# [49069 rows x 4 columns]

# %%
df_asset= df_asset.drop_duplicates()

# %%
df_asset["Date"] = df_asset.index
df_asset.drop_duplicates(subset=['Date', 'Instrument'])
df_asset.pivot(index='Date', columns='Instrument', values='Price Close')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/nr/3vs7wdfj1mn1333tl23g4vy00000gn/T/ipykernel_31491/2862892727.py in <module>
#       1 df_asset["Date"] = df_asset.index
#       2 df_asset.drop_duplicates(subset=['Date', 'Instrument'])
# ----> 3 df_asset.pivot(index='Date', columns='Instrument', values='Price Close')
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in pivot(self, index, columns, values)
#    8565         from pandas.core.reshape.pivot import pivot
#    8566
# ...

# %%
df_asset_1 = pd.read_csv("Data/EVEN_TEST_New_1.csv", index_col="Date")
df_asset_2 =  pd.read_csv("Data/EVEN_TEST_New_2.csv", index_col="Date")
df_asset_2["Price Close"] = df_asset_2["Close Price"]
df_asset = pd.concat([df_asset_1,  df_asset_2])[["Instrument", "Price Close"]]
df_asset.index = pd.to_datetime(df_asset.index)
df_asset.index = df_asset.index.date
duplicated_indices = df_asset.index.duplicated(keep='last')
df_asset = df_asset[duplicated_indices]

# %%
df_asset = df_asset[df_asset.index > pd.to_datetime(dateEvent) - pd.DateOffset(days=i_start)]
df_asset= df_asset[df_asset.index < pd.to_datetime(dateEvent) + pd.DateOffset(days=i_end)]

# %%
# Pivot the table
pivot_data = data.pivot(index='Date', columns='Instrument', values='Price Close')

# Display the first few rows of the pivoted data
pivot_data.head()
# Out:
# Instrument            .BSESNTR  .HSIDVN  .IDCOT7TR  .MERG0BC  .MIAPJ0000PUS  \
# Date
# NaN                        NaN      NaN        NaN       NaN            NaN
# 1981-01-02T00:00:00Z       NaN      NaN        NaN       NaN            NaN
# 1981-01-05T00:00:00Z       NaN      NaN        NaN       NaN            NaN
# 1981-01-06T00:00:00Z       NaN      NaN        NaN       NaN            NaN
# 1981-01-07T00:00:00Z       NaN      NaN        NaN       NaN            NaN
#
# Instrument            .MIWD00000PUS  .N225NTR  .NIFTRI  .SETI  .SPXTR  .SX5GR  \
# Date
# NaN                             NaN       NaN      NaN    NaN     NaN     NaN
# 1981-01-02T00:00:00Z            NaN       NaN      NaN    NaN     NaN     NaN
# 1981-01-05T00:00:00Z            NaN       NaN      NaN    NaN     NaN     NaN
# 1981-01-06T00:00:00Z            NaN       NaN      NaN    NaN     NaN     NaN
# 1981-01-07T00:00:00Z            NaN       NaN      NaN    NaN     NaN     NaN
#
# ...

# %%
df_asset
# Out:
#            Instrument  Price Close        date
# 2008-03-20   NDXEX.DE       11.160  2008-03-20
# 2008-03-20   NDXEX.DE       11.160  2008-03-20
# 2008-03-20   NDXEX.DE       11.160  2008-03-20
# 2008-04-30   NDXEX.DE       12.600  2008-04-30
# 2008-05-23   NDXEX.DE       12.500  2008-05-23
# ...               ...          ...         ...
# 2009-09-03     IGSB.O       52.190  2009-09-03
# 2009-09-04     IGSB.O       52.090  2009-09-04
# 2009-09-08     IGSB.O       52.190  2009-09-08
# 2009-09-09     IGSB.O       52.180  2009-09-09
# 2009-09-10     IGSB.O       52.235  2009-09-10
#
# [4447 rows x 3 columns]

# %%
import seaborn as sns
import streamlit as st
import pandas as pd
import numpy as np

# Assuming that df_asset, dateEvent, i_start, and i_end are defined

# Create a DataFrame for storing returns of all assets
all_returns = pd.DataFrame(index=df_asset.index.unique())

for asset in df_asset.Instrument.unique():
    price = df_asset[df_asset['Instrument'] == asset]
    price["return"] = np.log(price["Price Close"] / price["Price Close"].shift(1))
    price = price[price.index > pd.to_datetime(dateEvent) - pd.DateOffset(days=i_start)]
    price = price[price.index < pd.to_datetime(dateEvent) + pd.DateOffset(days=i_end)]

    # Add this asset's returns to the DataFrame
    all_returns[asset] = price["return"]

# Calculate correlation matrix
corr_matrix = all_returns.corr()

# Plotting
plt.figure(figsize=(12, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
st.pyplot(plt)
plt.clf()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/nr/3vs7wdfj1mn1333tl23g4vy00000gn/T/ipykernel_31491/3226261662.py in <module>
#      12     price = df_asset[df_asset['Instrument'] == asset]
#      13     price["return"] = np.log(price["Price Close"] / price["Price Close"].shift(1))
# ---> 14     price = price[price.index > pd.to_datetime(dateEvent) - pd.DateOffset(days=i_start)]
#      15     price = price[price.index < pd.to_datetime(dateEvent) + pd.DateOffset(days=i_end)]
#      16
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      70         other = item_from_zerodim(other)
#      71
# ---> 72         return method(self, other)
#      73
#      74     return new_method
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arraylike.py in __gt__(self, other)
# ...

# %%
df_x =  pd.read_excel("Data/X.xls", index_col=0)

# %%
df_x
# Out:
#                      USCESIR  USCSIIINR  CAFCS00  USFCMFFMR  USAAIIN  CBOEPCR  \
# 0                        NaN        NaN      NaN        NaN      NaN      NaN
# 1999-12-31 00:00:00      NaN        NaN   94.555        NaN     15.0     0.42
# 2000-01-03 00:00:00      NaN        NaN   94.190        NaN     15.0     0.46
# 2000-01-04 00:00:00      NaN        NaN   94.205        NaN     15.0     0.55
# 2000-01-05 00:00:00      NaN        NaN   94.185        NaN     15.0     0.51
# ...                      ...        ...      ...        ...      ...      ...
# 2023-07-21 00:00:00     63.1        NaN   94.685        NaN      NaN     0.85
# 2023-07-24 00:00:00     65.2        NaN   94.680        NaN      NaN     0.82
# 2023-07-25 00:00:00     70.3        NaN   94.675        NaN      NaN     0.87
# 2023-07-31 00:00:00      NaN        NaN      NaN        NaN      NaN      NaN
# 2023-08-15 00:00:00      NaN        NaN      NaN        NaN      NaN      NaN
#
# ...

# %%
price = df_asset[df_asset['Instrument'] == option_asset ]
    
# Create a Plotly figure
fig = px.line(price, x=price .index, y=price["Price Close"])

fig.show()

# %%
# Create line plot
#price, x=price .index, y=price["Price Close"]

fig = go.Figure()
fig.add_trace(go.Scatter(x=price .index, y=price["Price Close"] , mode='lines'))

# Highlight certain regions: for example, x from 0.2 to 0.3 and from 0.6 to 0.7.
highlighted_regions = Recession.tail(5).USREC.to_dict()
for region in highlighted_regions:
    fig.add_shape(
        type='rect',
        xref='x', yref='paper',
        #x0=region['x0'], y0=0, x1=region['x1'], y1=1,
        fillcolor='LightSalmon', opacity=0.5, 
        layer="below", line_width=0,
    )

# Update layout
fig.update_layout(showlegend=False)

fig.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/nr/3vs7wdfj1mn1333tl23g4vy00000gn/T/ipykernel_31491/2124499262.py in <module>
#      11         type='rect',
#      12         xref='x', yref='paper',
# ---> 13         x0=region['x0'], y0=0, x1=region['x1'], y1=1,
#      14         fillcolor='LightSalmon', opacity=0.5,
#      15         layer="below", line_width=0,
#
# TypeError: string indices must be integers

# %%
fig.show()
